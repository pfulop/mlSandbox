# %%
import numpy as np

# %%
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
np.array([[1,2],[2,3],[3,4]])
# Out:
# array([[1, 2],
#        [2, 3],
#        [3, 4]])

# %%
a = np.random.normal(0,0.1, (25,25))

# %%
b = np.random.normal(0.5,0.8, (25,25))

# %%
a
# Out:
# array([[ 0.03442384,  0.04573265,  0.14608459,  0.11275247,  0.06496878,
#          0.13786888, -0.11900237, -0.03293389,  0.02086672, -0.1648243 ,
#         -0.18384075, -0.0539823 , -0.07491406, -0.09693412, -0.06766751,
#         -0.03667449, -0.14817557, -0.08253064,  0.05874531, -0.01010049,
#          0.07492923,  0.02001059,  0.04647655,  0.04514169,  0.0913827 ],
#        [-0.08469749, -0.00902142, -0.10102283,  0.06784292,  0.04076019,
#          0.07202996, -0.02422417, -0.0316675 , -0.05810555, -0.01660904,
#         -0.21966614,  0.00821995,  0.12363369,  0.1113766 ,  0.04579192,
#         -0.02934843,  0.04984881, -0.05434909, -0.19583063, -0.07500809,
#         -0.03196703, -0.0605086 , -0.03384641, -0.02985456,  0.00844664],
#        [ 0.19421001,  0.12349055,  0.11891093, -0.10344496,  0.09555389,
#         -0.07051481,  0.07614837, -0.07570337,  0.05607421,  0.13314972,
#          0.09886728, -0.04009323,  0.1227186 , -0.03990208,  0.03723281,
# ...

# %%
b
# Out:
# array([[  1.22504804e+00,   1.17866505e+00,   7.73071879e-02,
#          -5.79989560e-01,  -5.95513535e-01,   1.57749557e-01,
#           1.05071441e+00,   5.46408855e-01,   1.43297852e+00,
#           6.68013326e-01,   3.36810685e-01,   7.39591408e-02,
#           3.24866871e-01,   1.04904622e+00,   1.89009323e+00,
#          -6.52589385e-02,   1.11773997e+00,   1.76862902e-01,
#           1.74961542e+00,   7.63307034e-01,  -2.60649683e-01,
#           8.04598065e-01,  -5.85647186e-01,   8.55744955e-01,
#           1.08411694e+00],
#        [ -5.46533492e-01,   3.99256460e-01,   1.73374276e+00,
#           2.88924207e+00,  -6.40914741e-01,   1.16923469e+00,
#           4.06293226e-01,  -5.07976804e-02,   1.72216148e+00,
#           7.68832460e-01,   8.49427430e-01,   4.27407406e-02,
#           1.47272219e+00,   6.41028682e-01,   3.67434313e-01,
#           1.17082271e+00,  -4.02611210e-01,   1.38121248e+00,
#          -4.26428178e-01,  -6.49018982e-01,  -5.65207021e-01,
# ...

# %%
a + b
# Out:
# array([[  1.25947188e+00,   1.22439770e+00,   2.23391775e-01,
#          -4.67237092e-01,  -5.30544759e-01,   2.95618440e-01,
#           9.31712038e-01,   5.13474966e-01,   1.45384524e+00,
#           5.03189028e-01,   1.52969932e-01,   1.99768400e-02,
#           2.49952816e-01,   9.52112100e-01,   1.82242571e+00,
#           8.39490906e-02,   1.73746667e-01,   1.24626144e-01,
#          -2.50664990e-02,  -1.23813757e-01,  -3.93488232e-02,
#           4.59234742e-01,   1.15571485e-01,   5.65580979e-02,
# ...

# %%
a / 3
# Out:
# array([[ 0.01147461,  0.01524422,  0.04869486,  0.03758416,  0.02165626,
#          0.04595629, -0.03966746, -0.01097796,  0.00695557, -0.05494143,
#         -0.06128025, -0.0179941 , -0.02497135, -0.03231137, -0.02255584,
#         -0.01222483, -0.04939186, -0.02751021,  0.01958177, -0.00336683,
#          0.02497641,  0.0066702 ,  0.01549218,  0.01504723,  0.0304609 ],
#        [-0.0282325 , -0.00300714, -0.03367428,  0.02261431,  0.01358673,
#          0.02400999, -0.00807472, -0.01055583, -0.01936852, -0.00553635,
#         -0.07322205,  0.00273998,  0.04121123,  0.03712553,  0.01526397,
#         -0.00978281,  0.01661627, -0.01811636, -0.06527688, -0.0250027 ,
#         -0.01065568, -0.02016953, -0.01128214, -0.00995152,  0.00281555],
#        [ 0.06473667,  0.04116352,  0.03963698, -0.03448165,  0.0318513 ,
#         -0.02350494,  0.02538279, -0.02523446,  0.0186914 ,  0.04438324,
#          0.03295576, -0.01336441,  0.0409062 , -0.01330069,  0.01241094,
# ...

# %%
c = np.array([[3,3],[6,6]])

# %%
c
# Out:
# array([[3, 3],
#        [6, 6]])

# %%
c / 3
# Out:
# array([[ 1.,  1.],
#        [ 2.,  2.]])

# %%
c - 1
# Out:
# array([[2, 2],
#        [5, 5]])

# %%
c // 3
# Out:
# array([[1, 1],
#        [2, 2]])

# %%
c * 2
# Out:
# array([[ 6,  6],
#        [12, 12]])

# %%
d = np.array([[1,1],[2,2]])

# %%
d
# Out:
# array([[1, 1],
#        [2, 2]])

# %%
c - d
# Out:
# array([[2, 2],
#        [4, 4]])

# %%
c + d
# Out:
# array([[4, 4],
#        [8, 8]])

# %%
c / d
# Out:
# array([[ 3.,  3.],
#        [ 3.,  3.]])

# %%
c // d
# Out:
# array([[3, 3],
#        [3, 3]])

# %%
c ** 2
# Out:
# array([[ 9,  9],
#        [36, 36]])

# %%
e = np.array([1,2])

# %%
e
# Out:
# array([1, 2])

# %%
c * e
# Out:
# array([[ 3,  6],
#        [ 6, 12]])

# %%
c
# Out:
# array([[3, 3],
#        [6, 6]])

# %%
e
# Out:
# array([1, 2])

# %%
np.dot(c,e)
# Out:
# array([ 9, 18])

# %%
e = e.reshape(2,1)

# %%
np.dot(c,e)
# Out:
# array([[ 9],
#        [18]])

# %%
c * e
# Out:
# array([[ 3,  3],
#        [12, 12]])

# %%
a = np.array([[1],[2]])
b = np.array([[2,1]])

# %%
np.dot(a,b)
# Out:
# array([[2, 1],
#        [4, 2]])

# %%
np.dot(b,a)
# Out:
# array([[4]])
