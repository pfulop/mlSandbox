# %%
# %matplotlib inline
from PIL import Image
import numpy as np
from vgg16_avg import VGG16_Avg
import keras.backend as K
import keras
from keras.models import Model
from scipy.optimize import fmin_l_bfgs_b
from scipy.misc import imsave
from keras import metrics
import matplotlib.pyplot as plt
import scipy
# Out:
# Using TensorFlow backend.

# %%
img = Image.open('/run/media/backman/yay/dogbreedKeras/train/beagle/8fb070664c0597ae883da9195c281a66.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333 at 0x7FA158B613C8>

# %%
rn_mean = np.array([123.68, 116.779, 103.939], dtype=np.float32)

# %%
preproc = lambda x: (x - rn_mean)[:, :, :, ::-1]

# %%
deproc = lambda x,s: np.clip(x.reshape(s)[:, :, :, ::-1] + rn_mean, 0, 255)

# %%
img_arr = preproc(np.expand_dims(np.array(img), 0))
shp = img_arr.shape

# %%
shp
# Out:
# (1, 333, 500, 3)

# %%
model = VGG16_Avg(include_top=False)
# Out:
# /home/backman/mlSandbox/vgg16_avg.py:48: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", name="block1_conv1", padding="same")`
#   x = Convolution2D(64, 3, 3, activation='relu', border_mode='same', name='block1_conv1')(img_input)
# /home/backman/mlSandbox/vgg16_avg.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", name="block1_conv2", padding="same")`
#   x = Convolution2D(64, 3, 3, activation='relu', border_mode='same', name='block1_conv2')(x)
# /home/backman/mlSandbox/vgg16_avg.py:53: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu", name="block2_conv1", padding="same")`
#   x = Convolution2D(128, 3, 3, activation='relu', border_mode='same', name='block2_conv1')(x)
# /home/backman/mlSandbox/vgg16_avg.py:54: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu", name="block2_conv2", padding="same")`
#   x = Convolution2D(128, 3, 3, activation='relu', border_mode='same', name='block2_conv2')(x)
# /home/backman/mlSandbox/vgg16_avg.py:58: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu", name="block3_conv1", padding="same")`
#   x = Convolution2D(256, 3, 3, activation='relu', border_mode='same', name='block3_conv1')(x)
# /home/backman/mlSandbox/vgg16_avg.py:59: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu", name="block3_conv2", padding="same")`
#   x = Convolution2D(256, 3, 3, activation='relu', border_mode='same', name='block3_conv2')(x)
# /home/backman/mlSandbox/vgg16_avg.py:60: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu", name="block3_conv3", padding="same")`
#   x = Convolution2D(256, 3, 3, activation='relu', border_mode='same', name='block3_conv3')(x)
# /home/backman/mlSandbox/vgg16_avg.py:64: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu", name="block4_conv1", padding="same")`
#   x = Convolution2D(512, 3, 3, activation='relu', border_mode='same', name='block4_conv1')(x)
# /home/backman/mlSandbox/vgg16_avg.py:65: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu", name="block4_conv2", padding="same")`
#   x = Convolution2D(512, 3, 3, activation='relu', border_mode='same', name='block4_conv2')(x)
# /home/backman/mlSandbox/vgg16_avg.py:66: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu", name="block4_conv3", padding="same")`
#   x = Convolution2D(512, 3, 3, activation='relu', border_mode='same', name='block4_conv3')(x)
# /home/backman/mlSandbox/vgg16_avg.py:70: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu", name="block5_conv1", padding="same")`
#   x = Convolution2D(512, 3, 3, activation='relu', border_mode='same', name='block5_conv1')(x)
# /home/backman/mlSandbox/vgg16_avg.py:71: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu", name="block5_conv2", padding="same")`
#   x = Convolution2D(512, 3, 3, activation='relu', border_mode='same', name='block5_conv2')(x)
# /home/backman/mlSandbox/vgg16_avg.py:72: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu", name="block5_conv3", padding="same")`
#   x = Convolution2D(512, 3, 3, activation='relu', border_mode='same', name='block5_conv3')(x)

# %%
layer = model.get_layer('block5_conv1').output
layer_model = Model(model.input, layer)
targ = K.variable(layer_model.predict(img_arr))

# %%
class Evaluator(object):
    def __init__(self, f, shp): self.f, self.shp = f, shp
        
    def loss(self, x):
        loss_, self.grad_values = self.f([x.reshape(self.shp)])
        return loss_.astype(np.float64)

    def grads(self, x): return self.grad_values.flatten().astype(np.float64)

# %%
loss = K.sum(metrics.mse(layer, targ))
grads = K.gradients(loss, model.input)
fn = K.function([model.input], [loss]+grads)
evaluator = Evaluator(fn, shp)

# %%
def solve_image(eval_obj, niter, x):
    for i in range(niter):
        x, min_val, info = fmin_l_bfgs_b(eval_obj.loss, x.flatten(),
                                         fprime=eval_obj.grads, maxfun=20)
        x = np.clip(x, -127,127)
        print('Current loss value:', min_val)
        imsave(f'/run/media/backman/yay/styleResults/res_at_iteration_{i}.png', deproc(x.copy(), shp)[0])
    return x

# %%
rand_img = lambda shape: np.random.uniform(-2.5, 2.5, shape)/100
x = rand_img(shp)
plt.imshow(x[0]);

# %%
iterations=10

# %%
x = solve_image(evaluator, iterations, x)
# Out:
# Current loss value: 45887.7421875
# Current loss value: 11977.875
# Current loss value: 5731.78955078
# Current loss value: 3627.84228516
# Current loss value: 2737.25024414
# Current loss value: 2158.6484375
# Current loss value: 1792.17614746
# Current loss value: 1545.51586914
# Current loss value: 1374.36303711
# Current loss value: 1230.77990723

# %%
Image.open('/run/media/backman/yay/styleResults/res_at_iteration_9.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x333 at 0x7FA152CF9B00>

# %%
style = Image.open('/run/media/backman/yay/styleResults/style3.jpg')

# %%
style = style.resize(np.divide(style.size,2.7).astype('int32')); style
# Out:
# <PIL.Image.Image image mode=RGB size=179x112 at 0x7FA152CF9E80>

# %%
style_arr = preproc(np.expand_dims(style,0)[:,:,:,:3])
shp = style_arr.shape
shp
# Out:
# (1, 112, 179, 3)

# %%
model = VGG16_Avg(include_top=False, input_shape=shp[1:])
outputs = {l.name: l.output for l in model.layers}
# Out:
# /home/backman/mlSandbox/vgg16_avg.py:48: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", name="block1_conv1", padding="same")`
#   x = Convolution2D(64, 3, 3, activation='relu', border_mode='same', name='block1_conv1')(img_input)
# /home/backman/mlSandbox/vgg16_avg.py:49: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", name="block1_conv2", padding="same")`
#   x = Convolution2D(64, 3, 3, activation='relu', border_mode='same', name='block1_conv2')(x)
# /home/backman/mlSandbox/vgg16_avg.py:53: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu", name="block2_conv1", padding="same")`
#   x = Convolution2D(128, 3, 3, activation='relu', border_mode='same', name='block2_conv1')(x)
# /home/backman/mlSandbox/vgg16_avg.py:54: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu", name="block2_conv2", padding="same")`
#   x = Convolution2D(128, 3, 3, activation='relu', border_mode='same', name='block2_conv2')(x)
# /home/backman/mlSandbox/vgg16_avg.py:58: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu", name="block3_conv1", padding="same")`
#   x = Convolution2D(256, 3, 3, activation='relu', border_mode='same', name='block3_conv1')(x)
# /home/backman/mlSandbox/vgg16_avg.py:59: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu", name="block3_conv2", padding="same")`
#   x = Convolution2D(256, 3, 3, activation='relu', border_mode='same', name='block3_conv2')(x)
# /home/backman/mlSandbox/vgg16_avg.py:60: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu", name="block3_conv3", padding="same")`
#   x = Convolution2D(256, 3, 3, activation='relu', border_mode='same', name='block3_conv3')(x)
# /home/backman/mlSandbox/vgg16_avg.py:64: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu", name="block4_conv1", padding="same")`
#   x = Convolution2D(512, 3, 3, activation='relu', border_mode='same', name='block4_conv1')(x)
# /home/backman/mlSandbox/vgg16_avg.py:65: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu", name="block4_conv2", padding="same")`
#   x = Convolution2D(512, 3, 3, activation='relu', border_mode='same', name='block4_conv2')(x)
# /home/backman/mlSandbox/vgg16_avg.py:66: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu", name="block4_conv3", padding="same")`
#   x = Convolution2D(512, 3, 3, activation='relu', border_mode='same', name='block4_conv3')(x)
# /home/backman/mlSandbox/vgg16_avg.py:70: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu", name="block5_conv1", padding="same")`
#   x = Convolution2D(512, 3, 3, activation='relu', border_mode='same', name='block5_conv1')(x)
# /home/backman/mlSandbox/vgg16_avg.py:71: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu", name="block5_conv2", padding="same")`
#   x = Convolution2D(512, 3, 3, activation='relu', border_mode='same', name='block5_conv2')(x)
# /home/backman/mlSandbox/vgg16_avg.py:72: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu", name="block5_conv3", padding="same")`
#   x = Convolution2D(512, 3, 3, activation='relu', border_mode='same', name='block5_conv3')(x)

# %%
layers = [outputs['block{}_conv1'.format(o)] for o in range(1,3)]

# %%
layers_model = Model(model.input, layers)
targs = [K.variable(o) for o in layers_model.predict(style_arr)]

# %%
def gram_matrix(x):
    # We want each row to be a channel, and the columns to be flattened x,y locations
    features = K.batch_flatten(K.permute_dimensions(x, (2, 0, 1)))
    # The dot product of this with its transpose shows the correlation 
    # between each pair of channels
    return K.dot(features, K.transpose(features)) / x.get_shape().num_elements()

# %%
def style_loss(x, targ): return K.sum(metrics.mse(gram_matrix(x), gram_matrix(targ)))

# %%
loss = sum(style_loss(l1[0], l2[0]) for l1,l2 in zip(layers, targs))
grads = K.gradients(loss, model.input)
style_fn = K.function([model.input], [loss]+grads)
evaluator = Evaluator(style_fn, shp)

# %%
rand_img = lambda shape: np.random.uniform(-2.5, 2.5, shape)/1
x = rand_img(shp)
x = scipy.ndimage.filters.gaussian_filter(x, [0,2,2,0])

# %%
iterations=10
x = rand_img(shp)

# %%
x = solve_image(evaluator, iterations, x)
# Out:
# Current loss value: 3876583.0
# Current loss value: 145922.609375
# Current loss value: 20886.9140625
# Current loss value: 13145.2451172
# Current loss value: 10584.1923828
# Current loss value: 8849.82421875
# Current loss value: 7145.44335938
# Current loss value: 5912.13085938
# Current loss value: 5195.48535156
# Current loss value: 4596.92773438

# %%
Image.open('/run/media/backman/yay/styleResults/res_at_iteration_9.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=179x112 at 0x7FA1527BC710>

# %%
w,h = style.size
src = img_arr[:,:h,:w]

# %%
style_layers = [outputs['block{}_conv2'.format(o)] for o in range(1,6)]
content_name = 'block4_conv2'
content_layer = outputs[content_name]

# %%
style_model = Model(model.input, style_layers)
style_targs = [K.variable(o) for o in style_model.predict(style_arr)]

# %%
content_model = Model(model.input, content_layer)
content_targ = K.variable(content_model.predict(src))

# %%
style_wgts = [0.05,0.2,0.2,0.25,0.3]

# %%
loss = sum(style_loss(l1[0], l2[0])*w
           for l1,l2,w in zip(style_layers, style_targs, style_wgts))
loss += K.sum(metrics.mse(content_layer, content_targ))/10
grads = K.gradients(loss, model.input)
transfer_fn = K.function([model.input], [loss]+grads)

# %%
evaluator = Evaluator(transfer_fn, shp)

# %%
iterations=10
x = rand_img(shp)

# %%
x = solve_image(evaluator, iterations, x)
# Out:
# Current loss value: 5157834.5
# Current loss value: 3503215.25
# Current loss value: 2013661.125
# Current loss value: 982892.25
# Current loss value: 547965.4375
# Current loss value: 338944.4375
# Current loss value: 248442.1875
# Current loss value: 208090.96875
# Current loss value: 188788.203125
# Current loss value: 179665.53125

# %%
Image.open('/run/media/backman/yay/styleResults/res_at_iteration_9.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=179x112 at 0x7FA1527BC6A0>
